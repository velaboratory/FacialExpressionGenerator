# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
plt.figure(figsize=(10,10))
plt.imshow(mpimg.imread('../Output/Light10FemaleAdultblendShape1.AA_VI_01_PP_25_leapLeft.png'))
plt.scatter([238.795715,
             494.612885,
            451.283569],
            [311.898254,331.137665,317.7423], s = 20, c = 'r')
plt.show()
